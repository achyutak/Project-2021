# %% [markdown]
# <a href="https://colab.research.google.com/github/achyutak/Project-2021/blob/main/Part_3_Seq2Seq_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd drive/MyDrive/Project-2021/Test1/Shakespearizing-Modern-English/code/main/
# Out:
# /content/drive/MyDrive/Project-2021/Test1/Shakespearizing-Modern-English/code/main

# %%
if os.path.isdir('./tmp') != True:
  # %mkdir ./tmp

# %%
# !python2 mt_main.py preprocessing
# Out:
# Using TensorFlow backend.
# WARNING: Logging before flag parsing goes to stderr.
# W0413 08:31:21.455925 140632781469568 deprecation.py:323] From /usr/local/lib/python2.7/dist-packages/tensorflow_core/python/compat/v2_compat.py:88: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# USAGE:
#
# python mt_main.py train <num_of_iters> <model_name>
# OR
# python mt_main.py inference <saved_model_path> <greedy/beam>
# OR
# python mt_main.py debug
# OR
# python mt_main.py preprocessing
#
#
# PARAMS:
#  --  max_output_seq_length  =  24
#  --  lstm_cell_size  =  192
#  --  share_encoder_decoder_embeddings  =  True
#  --  use_sentinel_loss  =  False
#  --  use_pointer  =  False
#  --  use_additional_info_from_pretrained_embeddings  =  True
#  --  pretrained_embeddings_are_trainable  =  False
#  --  embeddings_dim  =  192
# ...

# %%
# !python2 mt_main.py train 6 seq2seq
# Out:
# Using TensorFlow backend.
# WARNING: Logging before flag parsing goes to stderr.
# W0413 08:53:51.623831 139770660845440 deprecation.py:323] From /usr/local/lib/python2.7/dist-packages/tensorflow_core/python/compat/v2_compat.py:88: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# USAGE:
#
# python mt_main.py train <num_of_iters> <model_name>
# OR
# python mt_main.py inference <saved_model_path> <greedy/beam>
# OR
# python mt_main.py debug
# OR
# python mt_main.py preprocessing
#
#
# PARAMS:
#  --  max_output_seq_length  =  24
#  --  lstm_cell_size  =  192
#  --  share_encoder_decoder_embeddings  =  True
#  --  use_sentinel_loss  =  False
#  --  use_pointer  =  False
#  --  use_additional_info_from_pretrained_embeddings  =  True
#  --  pretrained_embeddings_are_trainable  =  False
#  --  embeddings_dim  =  192
# ...

# %% [markdown]
# ## Model Evaluation

# %% [markdown]
# Replace the number in seq2seq4.ckpt with the step number that has the best validation BLEU in the next cell to get the inference

# %%
# !python2 mt_main.py inference tmp/seq2seq5.ckpt greedy
# Out:
# Streaming output truncated to the last 5000 lines.
# prediction:   come on , let's have to in the dark room and a command them after .
#
# GT:  ['my', 'niece', 'already', 'thinks', "he's", 'insane', '.', 'sentend']
# prediction:   my niece is already act so much .
#
# GT:  ["here's", 'more', 'insanity', 'for', 'us', '.', 'sentend']
# prediction:   more matter what a beautiful morning .
#
# i=  10
# GT:  ['if', 'this', 'letter', "doesn't", 'make', 'him', 'fight', ',', 'i', "don't", 'know', 'what', 'will', '.', 'sentend']
# prediction:   if this letter is all this , my legs doesn't have any way to him , my legs .
#
# GT:  ["i'll", 'give', 'it', 'to', 'him', '.', 'sentend']
# prediction:   i'll give it to him .
#
# GT:  ['you', 'might', 'have', 'a', 'great', 'opportunity', 'to', 'give', 'it', 'to', 'him', 'right', 'now', '.', 'sentend']
# prediction:   you may god be it for you , and it may be a good thing for you .
#
# ...

# %% [markdown]
# # Finding the BLEU and PINC of the best model

# %% [markdown]
# After running the inference command with the best model, replace the 6 in pointer_model6.ckpt.test.output with the step that generates the best model in the following cells

# %%
# !perl ../main/multi-bleu.perl -lc ../../data/test.original.nltktok < tmp/seq2seq5.ckpt.test.output
# Out:
# BLEU = 11.66, 44.0/16.8/7.5/3.3 (BP=1.000, ratio=1.066, hyp_len=17029, ref_len=15978)

# %%
# !perl ../main/PINC.perl -lc ../../data/test.original.nltktok < tmp/seq2seq5.ckpt.test.output
# Out:
# PINC= 82.10 (ratio=1.066, hyp_len=17029, ref_len=15978)
