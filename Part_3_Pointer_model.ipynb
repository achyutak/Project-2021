# %% [markdown]
# <a href="https://colab.research.google.com/github/achyutak/Project-2021/blob/main/Part_3_Pointer_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd drive/MyDrive/Project-2021/Test0/Shakespearizing-Modern-English/code/main/
# Out:
# /content/drive/MyDrive/Project-2021/Test0/Shakespearizing-Modern-English/code/main

# %%
if os.path.isdir('./tmp') != True:
  # %mkdir ./tmp

# %%
# !python2 mt_main.py preprocessing
# Out:
# Using TensorFlow backend.
# WARNING: Logging before flag parsing goes to stderr.
# W0413 07:10:04.747514 140028117112704 deprecation.py:323] From /usr/local/lib/python2.7/dist-packages/tensorflow_core/python/compat/v2_compat.py:88: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# USAGE:
#
# python mt_main.py train <num_of_iters> <model_name>
# OR
# python mt_main.py inference <saved_model_path> <greedy/beam>
# OR
# python mt_main.py debug
# OR
# python mt_main.py preprocessing
#
#
# PARAMS:
#  --  max_output_seq_length  =  24
#  --  lstm_cell_size  =  192
#  --  share_encoder_decoder_embeddings  =  True
#  --  use_sentinel_loss  =  False
#  --  use_pointer  =  True
#  --  use_additional_info_from_pretrained_embeddings  =  True
#  --  pretrained_embeddings_are_trainable  =  False
#  --  embeddings_dim  =  192
# ...

# %%
# !python2 mt_main.py train 10 pointer_model
# Out:
# Using TensorFlow backend.
# WARNING: Logging before flag parsing goes to stderr.
# W0413 07:11:00.826719 140326599624576 deprecation.py:323] From /usr/local/lib/python2.7/dist-packages/tensorflow_core/python/compat/v2_compat.py:88: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# USAGE:
#
# python mt_main.py train <num_of_iters> <model_name>
# OR
# python mt_main.py inference <saved_model_path> <greedy/beam>
# OR
# python mt_main.py debug
# OR
# python mt_main.py preprocessing
#
#
# PARAMS:
#  --  max_output_seq_length  =  24
#  --  lstm_cell_size  =  192
#  --  share_encoder_decoder_embeddings  =  True
#  --  use_sentinel_loss  =  False
#  --  use_pointer  =  True
#  --  use_additional_info_from_pretrained_embeddings  =  True
#  --  pretrained_embeddings_are_trainable  =  False
#  --  embeddings_dim  =  192
# ...

# %% [markdown]
# # Model Evaluation

# %% [markdown]
# Replace the number in pointer_model6.ckpt with the step number that has the best validation BLEU in the next cell to get the inference

# %%
# !python2 mt_main.py inference tmp/pointer_model6.ckpt greedy
# Out:
# Streaming output truncated to the last 5000 lines.
# prediction:   come , we'll have him in a dark room .
#
# GT:  ['my', 'niece', 'already', 'thinks', "he's", 'insane', '.', 'sentend']
# prediction:   my niece is already in the belief that he's mad .
#
# GT:  ["here's", 'more', 'insanity', 'for', 'us', '.', 'sentend']
# prediction:   more matter than a may morning .
#
# i=  10
# GT:  ['if', 'this', 'letter', "doesn't", 'make', 'him', 'fight', ',', 'i', "don't", 'know', 'what', 'will', '.', 'sentend']
# prediction:   if this letter move him , he legs not .
#
# GT:  ["i'll", 'give', 'it', 'to', 'him', '.', 'sentend']
# prediction:   i'll give it him .
#
# GT:  ['you', 'might', 'have', 'a', 'great', 'opportunity', 'to', 'give', 'it', 'to', 'him', 'right', 'now', '.', 'sentend']
# prediction:   you may be very fit for you .
#
# GT:  ["he's", 'unk', 'some', 'business', 'with', 'my', 'lady', ',', 'and', 'sooner', 'or', 'later', "he'll", 'leave', '.', 'sentend']
# ...

# %%
# !python2 mt_main.py inference tmp/pointer_model7.ckpt greedy
# Out:
# Streaming output truncated to the last 5000 lines.
# prediction:   come on we'll we'll get him in a dark room .
#
# GT:  ['my', 'niece', 'already', 'thinks', "he's", 'insane', '.', 'sentend']
# prediction:   my niece is already in the belief that he's mad .
#
# GT:  ["here's", 'more', 'insanity', 'for', 'us', '.', 'sentend']
# prediction:   more than a matter morning .
#
# i=  10
# GT:  ['if', 'this', 'letter', "doesn't", 'make', 'him', 'fight', ',', 'i', "don't", 'know', 'what', 'will', '.', 'sentend']
# prediction:   if this letter move him , he legs not not .
#
# GT:  ["i'll", 'give', 'it', 'to', 'him', '.', 'sentend']
# prediction:   i'll give it away .
#
# GT:  ['you', 'might', 'have', 'a', 'great', 'opportunity', 'to', 'give', 'it', 'to', 'him', 'right', 'now', '.', 'sentend']
# prediction:   you want to be very fit for you .
#
# GT:  ["he's", 'unk', 'some', 'business', 'with', 'my', 'lady', ',', 'and', 'sooner', 'or', 'later', "he'll", 'leave', '.', 'sentend']
# ...

# %% [markdown]
# # Finding the BLEU and PINC of the best model

# %% [markdown]
# After running the inference command with the best model, replace the 6 in pointer_model6.ckpt.test.output with the step that generates the best model in the following cells

# %%
# !perl ../main/multi-bleu.perl -lc ../../data/test.original.nltktok < tmp/pointer_model6.ckpt.test.output
# Out:
# BLEU = 30.87, 69.1/40.2/27.0/18.6 (BP=0.899, ratio=0.904, hyp_len=14439, ref_len=15978)

# %%
# !perl ../main/PINC.perl -lc ../../data/test.original.nltktok < tmp/pointer_model6.ckpt.test.output
# Out:
# PINC= 61.30 (ratio=0.904, hyp_len=14439, ref_len=15978)

# %% [markdown]
# # ///////

# %%
# %ls

# %%
# %rm alpha.p

# %%
# %cd ..
# Out:
# /content/drive/My Drive/Project-2021/Test0/Shakespearizing-Modern-English/code/main

# %%
# cd ..
# Out:
# /content/drive/My Drive/Project-2021/Test0/Shakespearizing-Modern-English/code

# %%
# %cd baselines/
# Out:
# /content/drive/My Drive/Project-2021/Test0/Shakespearizing-Modern-English/code/baselines

# %%
# !python2 dictionary_baseline.py ../../data/shakespeare.dict ../../data/test.modern.nltktok ../../data/test.dictBaseline
# Out:
# ["we're", 'bound', 'to', 'each', 'other', 'in', 'every', 'possible', 'way', ',', 'except', 'we', 'need', 'you', 'to', 'marry', 'us', '.']
# ["we're", 'bound', 'to', 'each', 'other', 'in', 'every', 'possible', 'way', ',', 'except', 'we', 'need', 'thou', 'to', 'marry', 'us', '.']

# %%
# cd ..

# %%
# cd code/main
# Out:
# /content/drive/My Drive/Project-2021/Test0/Shakespearizing-Modern-English/code/main

# %%
# !CUDA_VISIBLE_DEVICES="" python2 post_process.py tmp/pointer_model7.ckpt.test postProcess

# %%
# mkdir logs

# %%
# !CUDA_VISIBLE_DEVICES="" python2 post_process.py tmp/pointer_model7.ckpt.test write 5

# %%
# !python2 mt_main.py train 10 pointer_model

# %%
# from shutil import copy
# print("Copying the alpha file from main to main/tmp")
# copy('alpha.p', '/content/drive/MyDrive/Project-2021/Test0/Shakespearizing-Modern-English/code/main/tmp')
# %cd tmp/
# import os
# dst = "pointer_model" + input("Enter the iteration of the checkpoint that has your desired output to rename the alpha file") + ".ckpt.test.alpha"
# os.rename('alpha.p',dst)
# print("The alpha file is renamed to {}".format(dst))
# %cd ..
